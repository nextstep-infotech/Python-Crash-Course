# %% [markdown]
# # 20.1 Module in Python

# %% [markdown]
# A module is a file containing Python definitions and statements.

# %% [markdown]
# A module can define functions, classes, and variables.

# %% [markdown]
# A module can also include runnable code.

# %% [markdown]
# Grouping related code into a module makes the code easier to understand and use.

# %% [markdown]
# It also makes the code logically organized.

# %% [markdown]
# They are executed only the first time the module name is encountered in an import statement.

# %% [markdown]
# The file name is the module name with the suffix .py appended.

# %% [markdown]
# Ex:- mymodule.py

# %% [markdown]
# **Type of Modules:**

# %% [markdown]
# + User-defined Modules
#
# + Built-in Modules
#
#     Ex:- array, math, sys

# %% [markdown]
# ## When and Why use Module

# %% [markdown]
# Assume that you are building a very large project, it will very difficult to manage all logic within one single file so if you want to separate your similar logic to a separate file, you can use module.

# %% [markdown]
# It will not only separate your logics but also help you to debug your code easily as you know which logic is defined in which module.

# %% [markdown]
# When a module is developed, it can be reused in any program that needs that module.

# %% [markdown]
# ## Creating a Module

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# **Suppose we want to create a module which do addition and subtraction.**

# %% [markdown]
# Now, save that in calc.py, which we can import later in another file.

# %% [markdown]
# ## How to use Module

# %% [markdown]
# import statment is used to import modules.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# import module_name

# %% [markdown]
# import module_name as alias_name

# %% [markdown]
# from module_name import var_name, f_name, class_name, method_name....

# %% [markdown]
# from module_name import f_name as alias_f_name

# %% [markdown]
# from module_name import *

# %% [markdown]
# **Note -  Modules can import other modules.**
