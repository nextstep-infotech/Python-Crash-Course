# %%
import os

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/os.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
#       - os.altsep is the alternate pathname separator (None or '/')
#       - os.pathsep is the component separator used in $PATH etc
#       - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#       - os.defpath is the default search path for executables
#       - os.devnull is the file path of the null device ('/dev/null', etc.)
#
#     Programs that import and use 'os' stand a better chance of being
#     portable between different platforms.  Of course, they must then
#     only use functions that are defined by all platforms (e.g., unlink
#     and opendir), and leave all pathname manipulation to os.path
#     (e.g., split and join).
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         builtins.OSError
#     builtins.object
#         nt.DirEntry
#     builtins.tuple(builtins.object)
#         nt.times_result
#         nt.uname_result
#         stat_result
#         statvfs_result
#         terminal_size
#
#     class DirEntry(builtins.object)
#      |  Methods defined here:
#      |
#      |  __fspath__(self, /)
#      |      Returns the path for the entry.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  inode(self, /)
#      |      Return inode of the entry; cached per entry.
#      |
#      |  is_dir(self, /, *, follow_symlinks=True)
#      |      Return True if the entry is a directory; cached per entry.
#      |
#      |  is_file(self, /, *, follow_symlinks=True)
#      |      Return True if the entry is a file; cached per entry.
#      |
#      |  is_symlink(self, /)
#      |      Return True if the entry is a symbolic link; cached per entry.
#      |
#      |  stat(self, /, *, follow_symlinks=True)
#      |      Return stat_result object for the entry; cached per entry.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods defined here:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  name
#      |      the entry's base filename, relative to scandir() "path" argument
#      |
#      |  path
#      |      the entry's full path name; equivalent to os.path.join(scandir_path, entry.name)
#
#     error = class OSError(Exception)
#      |  Base class for I/O related errors.
#      |
#      |  Method resolution order:
#      |      OSError
#      |      Exception
#      |      BaseException
#      |      object
#      |
#      |  Built-in subclasses:
#      |      BlockingIOError
#      |      ChildProcessError
#      |      ConnectionError
#      |      FileExistsError
#      |      ... and 7 other subclasses
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  characters_written
#      |
#      |  errno
#      |      POSIX exception code
#      |
#      |  filename
#      |      exception filename
#      |
#      |  filename2
#      |      second exception filename
#      |
#      |  strerror
#      |      exception strerror
#      |
#      |  winerror
#      |      Win32 exception code
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class stat_result(builtins.tuple)
#      |  stat_result(iterable=(), /)
#      |
#      |  stat_result: Result from stat, fstat, or lstat.
#      |
#      |  This object may be accessed either as a tuple of
#      |    (mode, ino, dev, nlink, uid, gid, size, atime, mtime, ctime)
#      |  or via the attributes st_mode, st_ino, st_dev, st_nlink, st_uid, and so on.
#      |
#      |  Posix/windows: If your platform supports st_blksize, st_blocks, st_rdev,
#      |  or st_flags, they are available as attributes only.
#      |
#      |  See os.stat for more information.
#      |
#      |  Method resolution order:
#      |      stat_result
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  st_atime
#      |      time of last access
#      |
#      |  st_atime_ns
#      |      time of last access in nanoseconds
#      |
#      |  st_ctime
#      |      time of last change
#      |
#      |  st_ctime_ns
#      |      time of last change in nanoseconds
#      |
#      |  st_dev
#      |      device
#      |
#      |  st_file_attributes
#      |      Windows file attribute bits
#      |
#      |  st_gid
#      |      group ID of owner
#      |
#      |  st_ino
#      |      inode
#      |
#      |  st_mode
#      |      protection bits
#      |
#      |  st_mtime
#      |      time of last modification
#      |
#      |  st_mtime_ns
#      |      time of last modification in nanoseconds
#      |
#      |  st_nlink
#      |      number of hard links
#      |
#      |  st_reparse_tag
#      |      Windows reparse tag
#      |
#      |  st_size
#      |      total size, in bytes
#      |
#      |  st_uid
#      |      user ID of owner
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __match_args__ = ('st_mode', 'st_ino', 'st_dev', 'st_nlink', 'st_uid',...
#      |
#      |  n_fields = 18
#      |
#      |  n_sequence_fields = 10
#      |
#      |  n_unnamed_fields = 3
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.tuple:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __contains__(self, key, /)
#      |      Return key in self.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(self, key, /)
#      |      Return self[key].
#      |
#      |  __getnewargs__(self, /)
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __mul__(self, value, /)
#      |      Return self*value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __rmul__(self, value, /)
#      |      Return value*self.
#      |
#      |  count(self, value, /)
#      |      Return number of occurrences of value.
#      |
#      |  index(self, value, start=0, stop=9223372036854775807, /)
#      |      Return first index of value.
#      |
#      |      Raises ValueError if the value is not present.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.tuple:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#
#     class statvfs_result(builtins.tuple)
#      |  statvfs_result(iterable=(), /)
#      |
#      |  statvfs_result: Result from statvfs or fstatvfs.
#      |
#      |  This object may be accessed either as a tuple of
#      |    (bsize, frsize, blocks, bfree, bavail, files, ffree, favail, flag, namemax),
#      |  or via the attributes f_bsize, f_frsize, f_blocks, f_bfree, and so on.
#      |
#      |  See os.statvfs for more information.
#      |
#      |  Method resolution order:
#      |      statvfs_result
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  f_bavail
#      |
#      |  f_bfree
#      |
#      |  f_blocks
#      |
#      |  f_bsize
#      |
#      |  f_favail
#      |
#      |  f_ffree
#      |
#      |  f_files
#      |
#      |  f_flag
#      |
#      |  f_frsize
#      |
#      |  f_fsid
#      |
#      |  f_namemax
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __match_args__ = ('f_bsize', 'f_frsize', 'f_blocks', 'f_bfree', 'f_bav...
#      |
#      |  n_fields = 11
#      |
#      |  n_sequence_fields = 10
#      |
#      |  n_unnamed_fields = 0
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.tuple:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __contains__(self, key, /)
#      |      Return key in self.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(self, key, /)
#      |      Return self[key].
#      |
#      |  __getnewargs__(self, /)
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __mul__(self, value, /)
#      |      Return self*value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __rmul__(self, value, /)
#      |      Return value*self.
#      |
#      |  count(self, value, /)
#      |      Return number of occurrences of value.
#      |
#      |  index(self, value, start=0, stop=9223372036854775807, /)
#      |      Return first index of value.
#      |
#      |      Raises ValueError if the value is not present.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.tuple:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#
#     class terminal_size(builtins.tuple)
#      |  terminal_size(iterable=(), /)
#      |
#      |  A tuple of (columns, lines) for holding terminal window size
#      |
#      |  Method resolution order:
#      |      terminal_size
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  columns
#      |      width of the terminal window in characters
#      |
#      |  lines
#      |      height of the terminal window in characters
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __match_args__ = ('columns', 'lines')
#      |
#      |  n_fields = 2
#      |
#      |  n_sequence_fields = 2
#      |
#      |  n_unnamed_fields = 0
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.tuple:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __contains__(self, key, /)
#      |      Return key in self.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(self, key, /)
#      |      Return self[key].
#      |
#      |  __getnewargs__(self, /)
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __mul__(self, value, /)
#      |      Return self*value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __rmul__(self, value, /)
#      |      Return value*self.
#      |
#      |  count(self, value, /)
#      |      Return number of occurrences of value.
#      |
#      |  index(self, value, start=0, stop=9223372036854775807, /)
#      |      Return first index of value.
#      |
#      |      Raises ValueError if the value is not present.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.tuple:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#
#     class times_result(builtins.tuple)
#      |  times_result(iterable=(), /)
#      |
#      |  times_result: Result from os.times().
#      |
#      |  This object may be accessed either as a tuple of
#      |    (user, system, children_user, children_system, elapsed),
#      |  or via the attributes user, system, children_user, children_system,
#      |  and elapsed.
#      |
#      |  See os.times for more information.
#      |
#      |  Method resolution order:
#      |      times_result
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  children_system
#      |      system time of children
#      |
#      |  children_user
#      |      user time of children
#      |
#      |  elapsed
#      |      elapsed time since an arbitrary point in the past
#      |
#      |  system
#      |      system time
#      |
#      |  user
#      |      user time
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __match_args__ = ('user', 'system', 'children_user', 'children_system'...
#      |
#      |  n_fields = 5
#      |
#      |  n_sequence_fields = 5
#      |
#      |  n_unnamed_fields = 0
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.tuple:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __contains__(self, key, /)
#      |      Return key in self.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(self, key, /)
#      |      Return self[key].
#      |
#      |  __getnewargs__(self, /)
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __mul__(self, value, /)
#      |      Return self*value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __rmul__(self, value, /)
#      |      Return value*self.
#      |
#      |  count(self, value, /)
#      |      Return number of occurrences of value.
#      |
#      |  index(self, value, start=0, stop=9223372036854775807, /)
#      |      Return first index of value.
#      |
#      |      Raises ValueError if the value is not present.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.tuple:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#
#     class uname_result(builtins.tuple)
#      |  uname_result(iterable=(), /)
#      |
#      |  uname_result: Result from os.uname().
#      |
#      |  This object may be accessed either as a tuple of
#      |    (sysname, nodename, release, version, machine),
#      |  or via the attributes sysname, nodename, release, version, and machine.
#      |
#      |  See os.uname for more information.
#      |
#      |  Method resolution order:
#      |      uname_result
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  machine
#      |      hardware identifier
#      |
#      |  nodename
#      |      name of machine on network (implementation-defined)
#      |
#      |  release
#      |      operating system release
#      |
#      |  sysname
#      |      operating system name
#      |
#      |  version
#      |      operating system version
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __match_args__ = ('sysname', 'nodename', 'release', 'version', 'machin...
#      |
#      |  n_fields = 5
#      |
#      |  n_sequence_fields = 5
#      |
#      |  n_unnamed_fields = 0
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.tuple:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __contains__(self, key, /)
#      |      Return key in self.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(self, key, /)
#      |      Return self[key].
#      |
#      |  __getnewargs__(self, /)
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __mul__(self, value, /)
#      |      Return self*value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __rmul__(self, value, /)
#      |      Return value*self.
#      |
#      |  count(self, value, /)
#      |      Return number of occurrences of value.
#      |
#      |  index(self, value, start=0, stop=9223372036854775807, /)
#      |      Return first index of value.
#      |
#      |      Raises ValueError if the value is not present.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.tuple:
#      |
#      |  __class_getitem__(...) from builtins.type
#      |      See PEP 585
#
# FUNCTIONS
#     _exit(status)
#         Exit to the system with specified status, without normal exit processing.
#
#     abort()
#         Abort the interpreter immediately.
#
#         This function 'dumps core' or otherwise fails in the hardest way possible
#         on the hosting operating system.  This function never returns.
#
#     access(path, mode, *, dir_fd=None, effective_ids=False, follow_symlinks=True)
#         Use the real uid/gid to test for access to a path.
#
#           path
#             Path to be tested; can be string, bytes, or a path-like object.
#           mode
#             Operating-system mode bitfield.  Can be F_OK to test existence,
#             or the inclusive-OR of R_OK, W_OK, and X_OK.
#           dir_fd
#             If not None, it should be a file descriptor open to a directory,
#             and path should be relative; path will then be relative to that
#             directory.
#           effective_ids
#             If True, access will use the effective uid/gid instead of
#             the real uid/gid.
#           follow_symlinks
#             If False, and the last element of the path is a symbolic link,
#             access will examine the symbolic link itself instead of the file
#             the link points to.
#
#         dir_fd, effective_ids, and follow_symlinks may not be implemented
#           on your platform.  If they are unavailable, using them will raise a
#           NotImplementedError.
#
#         Note that most operations will use the effective uid/gid, therefore this
#           routine can be used in a suid/sgid environment to test if the invoking user
#           has the specified access to the path.
#
#     chdir(path)
#         Change the current working directory to the specified path.
#
#         path may always be specified as a string.
#         On some platforms, path may also be specified as an open file descriptor.
#           If this functionality is unavailable, using it raises an exception.
#
#     chmod(path, mode, *, dir_fd=None, follow_symlinks=True)
#         Change the access permissions of a file.
#
#           path
#             Path to be modified.  May always be specified as a str, bytes, or a path-like object.
#             On some platforms, path may also be specified as an open file descriptor.
#             If this functionality is unavailable, using it raises an exception.
#           mode
#             Operating-system mode bitfield.
#           dir_fd
#             If not None, it should be a file descriptor open to a directory,
#             and path should be relative; path will then be relative to that
#             directory.
#           follow_symlinks
#             If False, and the last element of the path is a symbolic link,
#             chmod will modify the symbolic link itself instead of the file
#             the link points to.
#
#         It is an error to use dir_fd or follow_symlinks when specifying path as
#           an open file descriptor.
#         dir_fd and follow_symlinks may not be implemented on your platform.
#           If they are unavailable, using them will raise a NotImplementedError.
#
#     close(fd)
#         Close a file descriptor.
#
#     closerange(fd_low, fd_high, /)
#         Closes all file descriptors in [fd_low, fd_high), ignoring errors.
#
#     cpu_count()
#         Return the number of CPUs in the system; return None if indeterminable.
#
#         This number is not equivalent to the number of CPUs the current process can
#         use.  The number of usable CPUs can be obtained with
#         ``len(os.sched_getaffinity(0))``
#
#     device_encoding(fd)
#         Return a string describing the encoding of a terminal's file descriptor.
#
#         The file descriptor must be attached to a terminal.
#         If the device is not a terminal, return None.
#
#     dup(fd, /)
#         Return a duplicate of a file descriptor.
#
#     dup2(fd, fd2, inheritable=True)
#         Duplicate file descriptor.
#
#     execl(file, *args)
#         execl(file, *args)
#
#         Execute the executable file with argument list args, replacing the
#         current process.
#
#     execle(file, *args)
#         execle(file, *args, env)
#
#         Execute the executable file with argument list args and
#         environment env, replacing the current process.
#
#     execlp(file, *args)
#         execlp(file, *args)
#
#         Execute the executable file (which is searched for along $PATH)
#         with argument list args, replacing the current process.
#
#     execlpe(file, *args)
#         execlpe(file, *args, env)
#
#         Execute the executable file (which is searched for along $PATH)
#         with argument list args and environment env, replacing the current
#         process.
#
#     execv(path, argv, /)
#         Execute an executable path with arguments, replacing current process.
#
#         path
#           Path of executable file.
#         argv
#           Tuple or list of strings.
#
#     execve(path, argv, env)
#         Execute an executable path with arguments, replacing current process.
#
#         path
#           Path of executable file.
#         argv
#           Tuple or list of strings.
#         env
#           Dictionary of strings mapping to strings.
#
#     execvp(file, args)
#         execvp(file, args)
#
#         Execute the executable file (which is searched for along $PATH)
#         with argument list args, replacing the current process.
#         args may be a list or tuple of strings.
#
#     execvpe(file, args, env)
#         execvpe(file, args, env)
#
#         Execute the executable file (which is searched for along $PATH)
#         with argument list args and environment env, replacing the
#         current process.
#         args may be a list or tuple of strings.
#
#     fdopen(fd, mode='r', buffering=-1, encoding=None, *args, **kwargs)
#         # Supply os.fdopen()
#
#     fsdecode(filename)
#         Decode filename (an os.PathLike, bytes, or str) from the filesystem
#         encoding with 'surrogateescape' error handler, return str unchanged. On
#         Windows, use 'strict' error handler if the file system encoding is
#         'mbcs' (which is the default encoding).
#
#     fsencode(filename)
#         Encode filename (an os.PathLike, bytes, or str) to the filesystem
#         encoding with 'surrogateescape' error handler, return bytes unchanged.
#         On Windows, use 'strict' error handler if the file system encoding is
#         'mbcs' (which is the default encoding).
#
#     fspath(path)
#         Return the file system path representation of the object.
#
#         If the object is str or bytes, then allow it to pass through as-is. If the
#         object defines __fspath__(), then return the result of that method. All other
#         types raise a TypeError.
#
#     fstat(fd)
#         Perform a stat system call on the given file descriptor.
#
#         Like stat(), but for an open file descriptor.
#         Equivalent to os.stat(fd).
#
#     fsync(fd)
#         Force write of fd to disk.
#
#     ftruncate(fd, length, /)
#         Truncate a file, specified by file descriptor, to a specific length.
#
#     get_exec_path(env=None)
#         Returns the sequence of directories that will be searched for the
#         named executable (similar to a shell) when launching a process.
#
#         *env* must be an environment variable dict or None.  If *env* is None,
#         os.environ will be used.
#
#     get_handle_inheritable(handle, /)
#         Get the close-on-exe flag of the specified file descriptor.
#
#     get_inheritable(fd, /)
#         Get the close-on-exe flag of the specified file descriptor.
#
#     get_terminal_size(...)
#         Return the size of the terminal window as (columns, lines).
#
#         The optional argument fd (default standard output) specifies
#         which file descriptor should be queried.
#
#         If the file descriptor is not connected to a terminal, an OSError
#         is thrown.
#
#         This function will only be defined if an implementation is
#         available for this system.
#
#         shutil.get_terminal_size is the high-level function which should
#         normally be used, os.get_terminal_size is the low-level implementation.
#
#     getcwd()
#         Return a unicode string representing the current working directory.
#
#     getcwdb()
#         Return a bytes string representing the current working directory.
#
#     getenv(key, default=None)
#         Get an environment variable, return None if it doesn't exist.
#         The optional second argument can specify an alternate default.
#         key, default and the result are str.
#
#     getlogin()
#         Return the actual login name.
#
#     getpid()
#         Return the current process id.
#
#     getppid()
#         Return the parent's process id.
#
#         If the parent process has already exited, Windows machines will still
#         return its id; others systems will return the id of the 'init' process (1).
#
#     isatty(fd, /)
#         Return True if the fd is connected to a terminal.
#
#         Return True if the file descriptor is an open file descriptor
#         connected to the slave end of a terminal.
#
#     kill(pid, signal, /)
#         Kill a process with a signal.
#
#     link(src, dst, *, src_dir_fd=None, dst_dir_fd=None, follow_symlinks=True)
#         Create a hard link to a file.
#
#         If either src_dir_fd or dst_dir_fd is not None, it should be a file
#           descriptor open to a directory, and the respective path string (src or dst)
#           should be relative; the path will then be relative to that directory.
#         If follow_symlinks is False, and the last element of src is a symbolic
#           link, link will create a link to the symbolic link itself instead of the
#           file the link points to.
#         src_dir_fd, dst_dir_fd, and follow_symlinks may not be implemented on your
#           platform.  If they are unavailable, using them will raise a
#           NotImplementedError.
#
#     listdir(path=None)
#         Return a list containing the names of the files in the directory.
#
#         path can be specified as either str, bytes, or a path-like object.  If path is bytes,
#           the filenames returned will also be bytes; in all other circumstances
#           the filenames returned will be str.
#         If path is None, uses the path='.'.
#         On some platforms, path may also be specified as an open file descriptor;\
#           the file descriptor must refer to a directory.
#           If this functionality is unavailable, using it raises NotImplementedError.
#
#         The list is in arbitrary order.  It does not include the special
#         entries '.' and '..' even if they are present in the directory.
#
#     lseek(fd, position, how, /)
#         Set the position of a file descriptor.  Return the new position.
#
#         Return the new cursor position in number of bytes
#         relative to the beginning of the file.
#
#     lstat(path, *, dir_fd=None)
#         Perform a stat system call on the given path, without following symbolic links.
#
#         Like stat(), but do not follow symbolic links.
#         Equivalent to stat(path, follow_symlinks=False).
#
#     makedirs(name, mode=511, exist_ok=False)
#         makedirs(name [, mode=0o777][, exist_ok=False])
#
#         Super-mkdir; create a leaf directory and all intermediate ones.  Works like
#         mkdir, except that any intermediate path segment (not just the rightmost)
#         will be created if it does not exist. If the target directory already
#         exists, raise an OSError if exist_ok is False. Otherwise no exception is
#         raised.  This is recursive.
#
#     mkdir(path, mode=511, *, dir_fd=None)
#         Create a directory.
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#         The mode argument is ignored on Windows. Where it is used, the current umask
#         value is first masked out.
#
#     open(path, flags, mode=511, *, dir_fd=None)
#         Open a file for low level IO.  Returns a file descriptor (integer).
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#     pipe()
#         Create a pipe.
#
#         Returns a tuple of two file descriptors:
#           (read_fd, write_fd)
#
#     popen(cmd, mode='r', buffering=-1)
#         # Supply os.popen()
#
#     putenv(name, value, /)
#         Change or add an environment variable.
#
#     read(fd, length, /)
#         Read from a file descriptor.  Returns a bytes object.
#
#     readlink(path, *, dir_fd=None)
#         Return a string representing the path to which the symbolic link points.
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#         and path should be relative; path will then be relative to that directory.
#
#         dir_fd may not be implemented on your platform.  If it is unavailable,
#         using it will raise a NotImplementedError.
#
#     remove(path, *, dir_fd=None)
#         Remove a file (same as unlink()).
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#     removedirs(name)
#         removedirs(name)
#
#         Super-rmdir; remove a leaf directory and all empty intermediate
#         ones.  Works like rmdir except that, if the leaf directory is
#         successfully removed, directories corresponding to rightmost path
#         segments will be pruned away until either the whole path is
#         consumed or an error occurs.  Errors during this latter phase are
#         ignored -- they generally mean that a directory was not empty.
#
#     rename(src, dst, *, src_dir_fd=None, dst_dir_fd=None)
#         Rename a file or directory.
#
#         If either src_dir_fd or dst_dir_fd is not None, it should be a file
#           descriptor open to a directory, and the respective path string (src or dst)
#           should be relative; the path will then be relative to that directory.
#         src_dir_fd and dst_dir_fd, may not be implemented on your platform.
#           If they are unavailable, using them will raise a NotImplementedError.
#
#     renames(old, new)
#         renames(old, new)
#
#         Super-rename; create directories as necessary and delete any left
#         empty.  Works like rename, except creation of any intermediate
#         directories needed to make the new pathname good is attempted
#         first.  After the rename, directories corresponding to rightmost
#         path segments of the old name will be pruned until either the
#         whole path is consumed or a nonempty directory is found.
#
#         Note: this function can fail with the new directory structure made
#         if you lack permissions needed to unlink the leaf directory or
#         file.
#
#     replace(src, dst, *, src_dir_fd=None, dst_dir_fd=None)
#         Rename a file or directory, overwriting the destination.
#
#         If either src_dir_fd or dst_dir_fd is not None, it should be a file
#           descriptor open to a directory, and the respective path string (src or dst)
#           should be relative; the path will then be relative to that directory.
#         src_dir_fd and dst_dir_fd, may not be implemented on your platform.
#           If they are unavailable, using them will raise a NotImplementedError.
#
#     rmdir(path, *, dir_fd=None)
#         Remove a directory.
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#     scandir(path=None)
#         Return an iterator of DirEntry objects for given path.
#
#         path can be specified as either str, bytes, or a path-like object.  If path
#         is bytes, the names of yielded DirEntry objects will also be bytes; in
#         all other circumstances they will be str.
#
#         If path is None, uses the path='.'.
#
#     set_handle_inheritable(handle, inheritable, /)
#         Set the inheritable flag of the specified handle.
#
#     set_inheritable(fd, inheritable, /)
#         Set the inheritable flag of the specified file descriptor.
#
#     spawnl(mode, file, *args)
#         spawnl(mode, file, *args) -> integer
#
#         Execute file with arguments from args in a subprocess.
#         If mode == P_NOWAIT return the pid of the process.
#         If mode == P_WAIT return the process's exit code if it exits normally;
#         otherwise return -SIG, where SIG is the signal that killed it.
#
#     spawnle(mode, file, *args)
#         spawnle(mode, file, *args, env) -> integer
#
#         Execute file with arguments from args in a subprocess with the
#         supplied environment.
#         If mode == P_NOWAIT return the pid of the process.
#         If mode == P_WAIT return the process's exit code if it exits normally;
#         otherwise return -SIG, where SIG is the signal that killed it.
#
#     spawnv(mode, path, argv, /)
#         Execute the program specified by path in a new process.
#
#         mode
#           Mode of process creation.
#         path
#           Path of executable file.
#         argv
#           Tuple or list of strings.
#
#     spawnve(mode, path, argv, env, /)
#         Execute the program specified by path in a new process.
#
#         mode
#           Mode of process creation.
#         path
#           Path of executable file.
#         argv
#           Tuple or list of strings.
#         env
#           Dictionary of strings mapping to strings.
#
#     startfile(...)
#         Start a file with its associated application.
#
#         When "operation" is not specified or "open", this acts like
#         double-clicking the file in Explorer, or giving the file name as an
#         argument to the DOS "start" command: the file is opened with whatever
#         application (if any) its extension is associated.
#         When another "operation" is given, it specifies what should be done with
#         the file.  A typical operation is "print".
#
#         "arguments" is passed to the application, but should be omitted if the
#         file is a document.
#
#         "cwd" is the working directory for the operation. If "filepath" is
#         relative, it will be resolved against this directory. This argument
#         should usually be an absolute path.
#
#         "show_cmd" can be used to override the recommended visibility option.
#         See the Windows ShellExecute documentation for values.
#
#         startfile returns as soon as the associated application is launched.
#         There is no option to wait for the application to close, and no way
#         to retrieve the application's exit status.
#
#         The filepath is relative to the current directory.  If you want to use
#         an absolute path, make sure the first character is not a slash ("/");
#         the underlying Win32 ShellExecute function doesn't work if it is.
#
#     stat(path, *, dir_fd=None, follow_symlinks=True)
#         Perform a stat system call on the given path.
#
#           path
#             Path to be examined; can be string, bytes, a path-like object or
#             open-file-descriptor int.
#           dir_fd
#             If not None, it should be a file descriptor open to a directory,
#             and path should be a relative string; path will then be relative to
#             that directory.
#           follow_symlinks
#             If False, and the last element of the path is a symbolic link,
#             stat will examine the symbolic link itself instead of the file
#             the link points to.
#
#         dir_fd and follow_symlinks may not be implemented
#           on your platform.  If they are unavailable, using them will raise a
#           NotImplementedError.
#
#         It's an error to use dir_fd or follow_symlinks when specifying path as
#           an open file descriptor.
#
#     strerror(code, /)
#         Translate an error code to a message string.
#
#     symlink(src, dst, target_is_directory=False, *, dir_fd=None)
#         Create a symbolic link pointing to src named dst.
#
#         target_is_directory is required on Windows if the target is to be
#           interpreted as a directory.  (On Windows, symlink requires
#           Windows 6.0 or greater, and raises a NotImplementedError otherwise.)
#           target_is_directory is ignored on non-Windows platforms.
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#     system(command)
#         Execute the command in a subshell.
#
#     times()
#         Return a collection containing process timing information.
#
#         The object returned behaves like a named tuple with these fields:
#           (utime, stime, cutime, cstime, elapsed_time)
#         All fields are floating point numbers.
#
#     truncate(path, length)
#         Truncate a file, specified by path, to a specific length.
#
#         On some platforms, path may also be specified as an open file descriptor.
#           If this functionality is unavailable, using it raises an exception.
#
#     umask(mask, /)
#         Set the current numeric umask and return the previous umask.
#
#     unlink(path, *, dir_fd=None)
#         Remove a file (same as remove()).
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         dir_fd may not be implemented on your platform.
#           If it is unavailable, using it will raise a NotImplementedError.
#
#     unsetenv(name, /)
#         Delete an environment variable.
#
#     urandom(size, /)
#         Return a bytes object containing random bytes suitable for cryptographic use.
#
#     utime(...)
#         Set the access and modified time of path.
#
#         path may always be specified as a string.
#         On some platforms, path may also be specified as an open file descriptor.
#           If this functionality is unavailable, using it raises an exception.
#
#         If times is not None, it must be a tuple (atime, mtime);
#             atime and mtime should be expressed as float seconds since the epoch.
#         If ns is specified, it must be a tuple (atime_ns, mtime_ns);
#             atime_ns and mtime_ns should be expressed as integer nanoseconds
#             since the epoch.
#         If times is None and ns is unspecified, utime uses the current time.
#         Specifying tuples for both times and ns is an error.
#
#         If dir_fd is not None, it should be a file descriptor open to a directory,
#           and path should be relative; path will then be relative to that directory.
#         If follow_symlinks is False, and the last element of the path is a symbolic
#           link, utime will modify the symbolic link itself instead of the file the
#           link points to.
#         It is an error to use dir_fd or follow_symlinks when specifying path
#           as an open file descriptor.
#         dir_fd and follow_symlinks may not be available on your platform.
#           If they are unavailable, using them will raise a NotImplementedError.
#
#     waitpid(pid, options, /)
#         Wait for completion of a given process.
#
#         Returns a tuple of information regarding the process:
#             (pid, status << 8)
#
#         The options argument is ignored on Windows.
#
#     waitstatus_to_exitcode(status)
#         Convert a wait status to an exit code.
#
#         On Unix:
#
#         * If WIFEXITED(status) is true, return WEXITSTATUS(status).
#         * If WIFSIGNALED(status) is true, return -WTERMSIG(status).
#         * Otherwise, raise a ValueError.
#
#         On Windows, return status shifted right by 8 bits.
#
#         On Unix, if the process is being traced or if waitpid() was called with
#         WUNTRACED option, the caller must first check if WIFSTOPPED(status) is true.
#         This function must not be called if WIFSTOPPED(status) is true.
#
#     walk(top, topdown=True, onerror=None, followlinks=False)
#         Directory tree generator.
#
#         For each directory in the directory tree rooted at top (including top
#         itself, but excluding '.' and '..'), yields a 3-tuple
#
#             dirpath, dirnames, filenames
#
#         dirpath is a string, the path to the directory.  dirnames is a list of
#         the names of the subdirectories in dirpath (including symlinks to directories,
#         and excluding '.' and '..').
#         filenames is a list of the names of the non-directory files in dirpath.
#         Note that the names in the lists are just names, with no path components.
#         To get a full path (which begins with top) to a file or directory in
#         dirpath, do os.path.join(dirpath, name).
#
#         If optional arg 'topdown' is true or not specified, the triple for a
#         directory is generated before the triples for any of its subdirectories
#         (directories are generated top down).  If topdown is false, the triple
#         for a directory is generated after the triples for all of its
#         subdirectories (directories are generated bottom up).
#
#         When topdown is true, the caller can modify the dirnames list in-place
#         (e.g., via del or slice assignment), and walk will only recurse into the
#         subdirectories whose names remain in dirnames; this can be used to prune the
#         search, or to impose a specific order of visiting.  Modifying dirnames when
#         topdown is false has no effect on the behavior of os.walk(), since the
#         directories in dirnames have already been generated by the time dirnames
#         itself is generated. No matter the value of topdown, the list of
#         subdirectories is retrieved before the tuples for the directory and its
#         subdirectories are generated.
#
#         By default errors from the os.scandir() call are ignored.  If
#         optional arg 'onerror' is specified, it should be a function; it
#         will be called with one argument, an OSError instance.  It can
#         report the error to continue with the walk, or raise the exception
#         to abort the walk.  Note that the filename is available as the
#         filename attribute of the exception object.
#
#         By default, os.walk does not follow symbolic links to subdirectories on
#         systems that support them.  In order to get this functionality, set the
#         optional argument 'followlinks' to true.
#
#         Caution:  if you pass a relative pathname for top, don't change the
#         current working directory between resumptions of walk.  walk never
#         changes the current directory, and assumes that the client doesn't
#         either.
#
#         Example:
#
#         import os
#         from os.path import join, getsize
#         for root, dirs, files in os.walk('python/Lib/email'):
#             print(root, "consumes", end="")
#             print(sum(getsize(join(root, name)) for name in files), end="")
#             print("bytes in", len(files), "non-directory files")
#             if 'CVS' in dirs:
#                 dirs.remove('CVS')  # don't visit CVS directories
#
#     write(fd, data, /)
#         Write a bytes object to a file descriptor.
#
# DATA
#     F_OK = 0
#     O_APPEND = 8
#     O_BINARY = 32768
#     O_CREAT = 256
#     O_EXCL = 1024
#     O_NOINHERIT = 128
#     O_RANDOM = 16
#     O_RDONLY = 0
#     O_RDWR = 2
#     O_SEQUENTIAL = 32
#     O_SHORT_LIVED = 4096
#     O_TEMPORARY = 64
#     O_TEXT = 16384
#     O_TRUNC = 512
#     O_WRONLY = 1
#     P_DETACH = 4
#     P_NOWAIT = 1
#     P_NOWAITO = 3
#     P_OVERLAY = 2
#     P_WAIT = 0
#     R_OK = 4
#     SEEK_CUR = 1
#     SEEK_END = 2
#     SEEK_SET = 0
#     TMP_MAX = 2147483647
#     W_OK = 2
#     X_OK = 1
#     __all__ = ['altsep', 'curdir', 'pardir', 'sep', 'pathsep', 'linesep', ...
#     altsep = '/'
#     curdir = '.'
#     defpath = r'.;C:\bin'
#     devnull = 'nul'
#     environ = environ({'ALLUSERSPROFILE': 'C:\\ProgramData', '...D': 'modu...
#     extsep = '.'
#     linesep = '\r\n'
#     name = 'nt'
#     pardir = '..'
#     pathsep = ';'
#     sep = r'\'
#     supports_bytes_environ = False
#
# FILE
#     c:\users\hp\appdata\local\programs\python\python310\lib\os.py

# %% [markdown]
# ## 1. os.getcwd and os.chdir

# %%
help(os.getcwd)
# Out:
# Help on built-in function getcwd in module nt:
#
# getcwd()
#     Return a unicode string representing the current working directory.

# %%
print(os.getcwd())
# Out:
# E:\For YT Videos\Courses\Python Crash Course\Nepali\20 Modules

# %%
help(os.chdir)
# Out:
# Help on built-in function chdir in module nt:
#
# chdir(path)
#     Change the current working directory to the specified path.
#
#     path may always be specified as a string.
#     On some platforms, path may also be specified as an open file descriptor.
#       If this functionality is unavailable, using it raises an exception.

# %%
os.chdir(r"E:\NextStepInfoTechCourses")

# %%
print(os.getcwd())
# Out:
# E:\NextStepInfoTechCourses

# %% [markdown]
# ## 2. os.listdir

# %%
help(os.listdir)
# Out:
# Help on built-in function listdir in module nt:
#
# listdir(path=None)
#     Return a list containing the names of the files in the directory.
#
#     path can be specified as either str, bytes, or a path-like object.  If path is bytes,
#       the filenames returned will also be bytes; in all other circumstances
#       the filenames returned will be str.
#     If path is None, uses the path='.'.
#     On some platforms, path may also be specified as an open file descriptor;\
#       the file descriptor must refer to a directory.
#       If this functionality is unavailable, using it raises NotImplementedError.
#
#     The list is in arbitrary order.  It does not include the special
#     entries '.' and '..' even if they are present in the directory.

# %%
os.listdir()
# Out:
# ['10 Python 10', 'FileTest2.txt', 'PythonProgramming', 'WorkshopProjects']

# %%
os.listdir(r"E:\For YT Videos\Courses\Python Crash Course\Nepali\20 Modules")
# Out:
# ['.ipynb_checkpoints',
#  '20.01 Module in Python.ipynb',
#  '20.02 Math Module.ipynb',
#  '20.03 Random Module.ipynb',
#  '20.04 Datetime Module Original.ipynb',
#  '20.04 Datetime Module.ipynb',
#  '20.05 OS Module Original.ipynb',
#  '20.05 OS Module.ipynb',
#  '20.06 time Module.ipynb',
#  '20.07 timeit Module.ipynb',
#  '20.08 Regex in Python.ipynb',
#  '20.09 getpass() and getuser() in Python.ipynb',
#  '20.10 sys module in Python.ipynb',
#  '20.11 functools and memoization.ipynb',
#  'calculator.py',
#  'main.py',
#  '__pycache__']

# %% [markdown]
# ## 3. os.mkdir, os.makedirs, os.rmdir and os.removedirs

# %%
help(os.mkdir)
# Out:
# Help on built-in function mkdir in module nt:
#
# mkdir(path, mode=511, *, dir_fd=None)
#     Create a directory.
#
#     If dir_fd is not None, it should be a file descriptor open to a directory,
#       and path should be relative; path will then be relative to that directory.
#     dir_fd may not be implemented on your platform.
#       If it is unavailable, using it will raise a NotImplementedError.
#
#     The mode argument is ignored on Windows. Where it is used, the current umask
#     value is first masked out.

# %%
os.mkdir("YouTube")

# %%
os.mkdir("YouTube/Python")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 os.mkdir("YouTube/Python")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'YouTube/Python'

# %%
help(os.rmdir)
# Out:
# Help on built-in function rmdir in module nt:
#
# rmdir(path, *, dir_fd=None)
#     Remove a directory.
#
#     If dir_fd is not None, it should be a file descriptor open to a directory,
#       and path should be relative; path will then be relative to that directory.
#     dir_fd may not be implemented on your platform.
#       If it is unavailable, using it will raise a NotImplementedError.

# %%
os.rmdir("YouTube")

# %%
help(os.makedirs)
# Out:
# Help on function makedirs in module os:
#
# makedirs(name, mode=511, exist_ok=False)
#     makedirs(name [, mode=0o777][, exist_ok=False])
#
#     Super-mkdir; create a leaf directory and all intermediate ones.  Works like
#     mkdir, except that any intermediate path segment (not just the rightmost)
#     will be created if it does not exist. If the target directory already
#     exists, raise an OSError if exist_ok is False. Otherwise no exception is
#     raised.  This is recursive.

# %%
os.makedirs("YouTube/Python")

# %%
help(os.removedirs)
# Out:
# Help on function removedirs in module os:
#
# removedirs(name)
#     removedirs(name)
#
#     Super-rmdir; remove a leaf directory and all empty intermediate
#     ones.  Works like rmdir except that, if the leaf directory is
#     successfully removed, directories corresponding to rightmost path
#     segments will be pruned away until either the whole path is
#     consumed or an error occurs.  Errors during this latter phase are
#     ignored -- they generally mean that a directory was not empty.

# %%
os.removedirs("YouTube/Python")

# %% [markdown]
# ## 4. os.rename

# %%
help(os.rename)
# Out:
# Help on built-in function rename in module nt:
#
# rename(src, dst, *, src_dir_fd=None, dst_dir_fd=None)
#     Rename a file or directory.
#
#     If either src_dir_fd or dst_dir_fd is not None, it should be a file
#       descriptor open to a directory, and the respective path string (src or dst)
#       should be relative; the path will then be relative to that directory.
#     src_dir_fd and dst_dir_fd, may not be implemented on your platform.
#       If they are unavailable, using them will raise a NotImplementedError.

# %%
os.rename('FileTest2.txt', 'TestFile2.txt')

# %% [markdown]
# ## 5. os.stat

# %%
help(os.stat)
# Out:
# Help on built-in function stat in module nt:
#
# stat(path, *, dir_fd=None, follow_symlinks=True)
#     Perform a stat system call on the given path.
#
#       path
#         Path to be examined; can be string, bytes, a path-like object or
#         open-file-descriptor int.
#       dir_fd
#         If not None, it should be a file descriptor open to a directory,
#         and path should be a relative string; path will then be relative to
#         that directory.
#       follow_symlinks
#         If False, and the last element of the path is a symbolic link,
#         stat will examine the symbolic link itself instead of the file
#         the link points to.
#
#     dir_fd and follow_symlinks may not be implemented
#       on your platform.  If they are unavailable, using them will raise a
#       NotImplementedError.
#
#     It's an error to use dir_fd or follow_symlinks when specifying path as
#       an open file descriptor.

# %%
os.stat("TestFile2.txt")
# Out:
# os.stat_result(st_mode=33206, st_ino=281474976716978, st_dev=12474489, st_nlink=1, st_uid=0, st_gid=0, st_size=102, st_atime=1667957398, st_mtime=1667553843, st_ctime=1667466876)

# %%
os.stat("TestFile2.txt").st_size
# Out:
# 102

# %%
os.stat("TestFile2.txt").st_atime
# Out:
# 1667959310.5886147

# %%
import time
access_time = time.ctime(os.stat("TestFile2.txt").st_atime)
print(access_time)
# Out:
# Wed Nov  9 07:46:50 2022

# %% [markdown]
# ## 6. os.walk()

# %%
help(os.walk)
# Out:
# Help on function walk in module os:
#
# walk(top, topdown=True, onerror=None, followlinks=False)
#     Directory tree generator.
#
#     For each directory in the directory tree rooted at top (including top
#     itself, but excluding '.' and '..'), yields a 3-tuple
#
#         dirpath, dirnames, filenames
#
#     dirpath is a string, the path to the directory.  dirnames is a list of
#     the names of the subdirectories in dirpath (including symlinks to directories,
#     and excluding '.' and '..').
#     filenames is a list of the names of the non-directory files in dirpath.
#     Note that the names in the lists are just names, with no path components.
#     To get a full path (which begins with top) to a file or directory in
#     dirpath, do os.path.join(dirpath, name).
#
#     If optional arg 'topdown' is true or not specified, the triple for a
#     directory is generated before the triples for any of its subdirectories
#     (directories are generated top down).  If topdown is false, the triple
#     for a directory is generated after the triples for all of its
#     subdirectories (directories are generated bottom up).
#
#     When topdown is true, the caller can modify the dirnames list in-place
#     (e.g., via del or slice assignment), and walk will only recurse into the
#     subdirectories whose names remain in dirnames; this can be used to prune the
#     search, or to impose a specific order of visiting.  Modifying dirnames when
#     topdown is false has no effect on the behavior of os.walk(), since the
#     directories in dirnames have already been generated by the time dirnames
#     itself is generated. No matter the value of topdown, the list of
#     subdirectories is retrieved before the tuples for the directory and its
#     subdirectories are generated.
#
#     By default errors from the os.scandir() call are ignored.  If
#     optional arg 'onerror' is specified, it should be a function; it
#     will be called with one argument, an OSError instance.  It can
#     report the error to continue with the walk, or raise the exception
#     to abort the walk.  Note that the filename is available as the
#     filename attribute of the exception object.
#
#     By default, os.walk does not follow symbolic links to subdirectories on
#     systems that support them.  In order to get this functionality, set the
#     optional argument 'followlinks' to true.
#
#     Caution:  if you pass a relative pathname for top, don't change the
#     current working directory between resumptions of walk.  walk never
#     changes the current directory, and assumes that the client doesn't
#     either.
#
#     Example:
#
#     import os
#     from os.path import join, getsize
#     for root, dirs, files in os.walk('python/Lib/email'):
#         print(root, "consumes", end="")
#         print(sum(getsize(join(root, name)) for name in files), end="")
#         print("bytes in", len(files), "non-directory files")
#         if 'CVS' in dirs:
#             dirs.remove('CVS')  # don't visit CVS directories

# %%
for dirpath, dirnames, filenames in os.walk(r"E:\NextStepInfoTechCourses"):
    print("Current Path: ", dirpath)
    print("Directories: ", dirnames)
    print("Files: ", filenames)
    print()
# Out:
# Current Path:  E:\NextStepInfoTechCourses
# Directories:  ['10 Python 10', 'PythonProgramming', 'WorkshopProjects']
# Files:  ['TestFile2.txt']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10
# Directories:  ['.ipynb_checkpoints', '01 Python Introduction and Setup', '02 Getting Started', '03 Conditional', '04 Loop', '05 String', '06 List', '07 Tuple', '08 Set', '09 Dictionary', '10 Function', '11 Ternary if and Comprehension', '12 Some Extra But Important Knowledge', '13 Object Oriented Programming', '14 Exception Handling', '15 VSCode and Virtual Environments', '16 Modules', '17 File Handling', 'Exercises', 'Project Works', 'Python-Projects']
# Files:  ['17 File Handling.zip', 'Project Works.zip']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\.ipynb_checkpoints
# Directories:  []
# Files:  ['Loops-checkpoint.ipynb', 'Tic Tac Toe-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup
# Directories:  ['.vscode', '1.0 Introduction to Programming', '1.1 Introduction To Python how python works', '1.2 How to Install Python', '1.3 How to run Python Program using Command Line Window, IDLE, Notepad', '1.4 How to install and run jupyter notebook']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\.vscode
# Directories:  []
# Files:  ['settings.json']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.0 Introduction to Programming
# Directories:  []
# Files:  ['Introduction To Programming.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.1 Introduction To Python how python works
# Directories:  []
# Files:  ['Introduction To Python.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.2 How to Install Python
# Directories:  []
# Files:  ['How to Install Python.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.3 How to run Python Program using Command Line Window, IDLE, Notepad
# Directories:  []
# Files:  ['How to run Python Program using Command Line Window, IDLE, Notepad.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.4 How to install and run jupyter notebook
# Directories:  ['.ipynb_checkpoints']
# Files:  ['How to install Anaconda and run jupyter notebook.pptx', 'Markdown in Jupyter Notebook.ipynb', 'ShristiPuri.jpg']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\01 Python Introduction and Setup\1.4 How to install and run jupyter notebook\.ipynb_checkpoints
# Directories:  []
# Files:  ['Markdown in Jupyter Notebook-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started
# Directories:  ['.ipynb_checkpoints', '2.1 Comments, Identifier, Reserved Words and Constant in Python', '2.2 Variable in Python', '2.3 Data Type in Python', '2.4 Declaring and Intializing Variables in Python', '2.5 Operators in Python', '2.6 Type Conversion in Python', '2.7 Print Function in Python', '2.8 Getting input from user in Python', '2.9 Escape Sequence in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.1 Comments, Identifier, Reserved Words and Constant in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Comments, Identifier, Reserved Words and Constant in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.1 Comments, Identifier, Reserved Words and Constant in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Comments, Identifier, Reserved Words and Constant in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.2 Variable in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Variables in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.2 Variable in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Variables in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.3 Data Type in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Data Type in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.3 Data Type in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Data Type in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.4 Declaring and Intializing Variables in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Declaring and Intializing Variables in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.4 Declaring and Intializing Variables in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Declaring and Intializing Variables in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.5 Operators in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Operators in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.5 Operators in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Operators in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.6 Type Conversion in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Implicit and Explicit Type Conversion in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.6 Type Conversion in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Implicit and Explicit Type Conversion in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.7 Print Function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Output Statement or Print Function in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.7 Print Function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Output Statement or Print Function in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.8 Getting input from user in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Getting input from user in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.8 Getting input from user in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Getting input from user in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.9 Escape Sequence in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Escape Sequence in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\02 Getting Started\2.9 Escape Sequence in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Escape Sequence in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional
# Directories:  ['.ipynb_checkpoints', '3.1 If Statement in Python', '3.2 Nested if Statement in Python', '3.3 if Statement with Logical Operator in Python', '3.4 Indentation in Python', '3.5 if else Statement in Python', '3.6 Nested if else Statement in Python', '3.7 if elif and if elif else Statement in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.1 If Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['If Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.1 If Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Exercise-checkpoint.ipynb', 'If Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.2 Nested if Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested if Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.2 Nested if Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Exercise-checkpoint.ipynb', 'Nested if Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.3 if Statement with Logical Operator in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['if Statement with Logical Operator in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.3 if Statement with Logical Operator in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['if Statement with Logical Operator in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.4 Indentation in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Indentation in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.4 Indentation in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Exercises-checkpoint.ipynb', 'Indentation in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.5 if else Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['if else Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.5 if else Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['if else Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.6 Nested if else Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested if else Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.6 Nested if else Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested if else Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.7 if elif and if elif else Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['if elif and if elif else Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\03 Conditional\3.7 if elif and if elif else Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['if elif and if elif else Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop
# Directories:  ['.ipynb_checkpoints', '4.1 range function in Python', '4.2 for loop and Nested for Loop in Python', '4.3 Enumerate function in Python', '4.4 While Loop and Nested while Loop in Python', '4.5 Break, Continue and Pass Statement in Python']
# Files:  ['f_loop.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.1 range function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['range function in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.1 range function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['range function in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.2 for loop and Nested for Loop in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['for loop and Nested for Loop in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.2 for loop and Nested for Loop in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['for loop and Nested for Loop in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.3 Enumerate function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Enumerate function in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.3 Enumerate function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Enumerate function in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.4 While Loop and Nested while Loop in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['While Loop and Nested while Loop in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.4 While Loop and Nested while Loop in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['While Loop and Nested while Loop in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.5 Break, Continue and Pass Statement in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Break, Continue and Pass Statement in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\04 Loop\4.5 Break, Continue and Pass Statement in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Break, Continue and Pass Statement in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String
# Directories:  ['.ipynb_checkpoints', '5.1 String in Python', '5.2 More on Strings', '5.3 f String formatting in Python', '5.4 String methods in Python']
# Files:  ['Assignment 5 - For Loop.ipynb', 'test.py', 'Untitled.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\.ipynb_checkpoints
# Directories:  []
# Files:  ['Assignment 5 - For Loop-checkpoint.ipynb', 'Untitled-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.1 String in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['String in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.1 String in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['String in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.2 More on Strings
# Directories:  ['.ipynb_checkpoints']
# Files:  ['More on Strings.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.2 More on Strings\.ipynb_checkpoints
# Directories:  []
# Files:  ['More on Strings-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.3 f String formatting in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['f String formatting in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.3 f String formatting in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['f String formatting in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.4 String methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['String methods in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\05 String\5.4 String methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['String methods in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List
# Directories:  ['6.1 List in Python', '6.2 List Methods in Python', '6.3 More on Lists', '6.4 Nested List in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.1 List in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['List in Python.ipynb', 'Untitled.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.1 List in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['List in Python-checkpoint.ipynb', 'Untitled-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.2 List Methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['List Methods in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.2 List Methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['List Methods in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.3 More on Lists
# Directories:  ['.ipynb_checkpoints']
# Files:  ['More on Lists.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.3 More on Lists\.ipynb_checkpoints
# Directories:  []
# Files:  ['More on Lists-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.4 Nested List in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested List in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\06 List\6.4 Nested List in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested List in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple
# Directories:  ['7.1 Tuple and Tuple methods in Python', '7.2 More on Tuple', '7.3 Nested Tuple in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.1 Tuple and Tuple methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Tuple and tuple methods in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.1 Tuple and Tuple methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Tuple and tuple methods in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.2 More on Tuple
# Directories:  ['.ipynb_checkpoints']
# Files:  ['More on Tuple.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.2 More on Tuple\.ipynb_checkpoints
# Directories:  []
# Files:  ['More on Tuple-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.3 Nested Tuple in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested Tuple in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\07 Tuple\7.3 Nested Tuple in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested Tuple in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set
# Directories:  ['8.1 Set Type in Python', '8.2 Set methods in Python', '8.3 Nested Set in Python (FrozenSet)']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.1 Set Type in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Set Type in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.1 Set Type in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Set Type in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.2 Set methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Set Methods in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.2 Set methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Set Methods in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.3 Nested Set in Python (FrozenSet)
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested Set in  Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\08 Set\8.3 Nested Set in Python (FrozenSet)\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested Set in  Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary
# Directories:  ['9.1 Dictionary in Python', '9.2 Dictionary methods in Python', '9.3 More on Dictionary', '9.4 Nested Dictionary in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.1 Dictionary in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Dictionary in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.1 Dictionary in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Dictionary in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.2 Dictionary methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Dictionary Methods in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.2 Dictionary methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Dictionary Methods in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.3 More on Dictionary
# Directories:  ['.ipynb_checkpoints']
# Files:  ['More on Dictionary.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.3 More on Dictionary\.ipynb_checkpoints
# Directories:  []
# Files:  ['More on Dictionary-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.4 Nested Dictionary in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested Dictionary in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\09 Dictionary\9.4 Nested Dictionary in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested Dictionary in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function
# Directories:  ['.ipynb_checkpoints', '10.1 Function and How Function Work in Python', '10.2 Local and Global Variable in Python', '10.3 Nested Function in Python', '10.4 Recursion in Python', '10.5 Anonymous Function or Lambda Expression in Python', '10.6 Function Decorator in Python']
# Files:  ['Function Decorator in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.1 Function and How Function Work in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Function and How Function Work in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.1 Function and How Function Work in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Function and How Function Work in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.2 Local and Global Variable in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Local and Global Variable in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.2 Local and Global Variable in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Local and Global Variable in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.3 Nested Function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested Function in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.3 Nested Function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested Function in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.4 Recursion in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Recursion in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.4 Recursion in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Recursion in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.5 Anonymous Function or Lambda Expression in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Anonymous Function or Lambda Expression in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.5 Anonymous Function or Lambda Expression in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Anonymous Function or Lambda Expression in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.6 Function Decorator in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['decore.py', 'Function Decorator in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\10 Function\10.6 Function Decorator in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Function Decorator in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension
# Directories:  ['.ipynb_checkpoints', '01 Ternary if', '02 List, Tuple, Set and Dictionary Comprehension in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension\01 Ternary if
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Ternary IF.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension\01 Ternary if\.ipynb_checkpoints
# Directories:  []
# Files:  ['Ternary IF-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension\02 List, Tuple, Set and Dictionary Comprehension in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['List, Tuple, Set and Dictionary Comprehension.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\11 Ternary if and Comprehension\02 List, Tuple, Set and Dictionary Comprehension in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['List, Tuple, Set and Dictionary Comprehension-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge
# Directories:  ['.ipynb_checkpoints', '01 Generator Function Yield Statement and Next Function in Python', '02 type() and isinstance() in Python with Examples', '03 len, max, min, sorted Function in Python', '04 zip method', '05 filter, map Function in Python', '06 Tips and Tricks in Python', '07 Getting Help in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\01 Generator Function Yield Statement and Next Function in Python
# Directories:  ['.ipynb_checkpoints', '.vscode']
# Files:  ['Generator.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\01 Generator Function Yield Statement and Next Function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Generator-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\01 Generator Function Yield Statement and Next Function in Python\.vscode
# Directories:  []
# Files:  ['settings.json']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\02 type() and isinstance() in Python with Examples
# Directories:  ['.ipynb_checkpoints']
# Files:  ['type() and isinstance().ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\02 type() and isinstance() in Python with Examples\.ipynb_checkpoints
# Directories:  []
# Files:  ['type() and isinstance()-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\03 len, max, min, sorted Function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['len, max, min,  sorted Function in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\03 len, max, min, sorted Function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['len, max, min,  sorted Function in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\04 zip method
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Zip method.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\04 zip method\.ipynb_checkpoints
# Directories:  []
# Files:  ['Zip method-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\05 filter, map Function in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['filter, map Function.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\05 filter, map Function in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['filter, map Function-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\06 Tips and Tricks in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Tips and Tricks in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\06 Tips and Tricks in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Tips and Tricks in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\07 Getting Help in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Getting Help in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\12 Some Extra But Important Knowledge\07 Getting Help in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Getting Help in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming
# Directories:  ['.ipynb_checkpoints', '01 Object Oriented Programming', '02 Class and Object in Python', '03 Constructor in Python', '04 Types of Variable in Python', '05 Types of  Method in Python', '06 Nested Class in Python', '07 Inheritance in Python', '08 Constructor in Inheritance', '09 Duck Typing and Strong Typing in Python', '10 Method Overloading, Method Overriding in Python', '11 Abstract Class, Abstract Method, Concrete Method and Interface', '12 Magic_Dunder Methods in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\01 Object Oriented Programming
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Object Oriented Programming.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\01 Object Oriented Programming\.ipynb_checkpoints
# Directories:  []
# Files:  ['Object Oriented Programming-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\02 Class and Object in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Class and Object.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\02 Class and Object in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Class and Object-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\03 Constructor in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Constructor.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\03 Constructor in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Constructor-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\04 Types of Variable in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Types of Variable.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\04 Types of Variable in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Types of Variable-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\05 Types of  Method in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Type of Methods.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\05 Types of  Method in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Type of Methods-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\06 Nested Class in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Nested Class in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\06 Nested Class in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Nested Class in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\07 Inheritance in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Inheritance in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\07 Inheritance in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Inheritance in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\08 Constructor in Inheritance
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Constructor in Inheritance.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\08 Constructor in Inheritance\.ipynb_checkpoints
# Directories:  []
# Files:  ['Constructor in Inheritance-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\09 Duck Typing and Strong Typing in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Duck and Strong Typing.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\09 Duck Typing and Strong Typing in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Duck and Strong Typing-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\10 Method Overloading, Method Overriding in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Method Overloading, Method Overriding in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\10 Method Overloading, Method Overriding in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Method Overloading, Method Overriding in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\11 Abstract Class, Abstract Method, Concrete Method and Interface
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Abstraction in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\11 Abstract Class, Abstract Method, Concrete Method and Interface\.ipynb_checkpoints
# Directories:  []
# Files:  ['Abstraction in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\12 Magic_Dunder Methods in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Magic or Dunder Methods.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\13 Object Oriented Programming\12 Magic_Dunder Methods in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Magic or Dunder Methods-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling
# Directories:  ['.ipynb_checkpoints', '01  Exception Handling and Builtin Exception in Python', '02 User Defined Exception in Python', '03 Difference between Error and Exception and Warning in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\01  Exception Handling and Builtin Exception in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Exception Handling and Builtin Exception.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\01  Exception Handling and Builtin Exception in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Exception Handling and Builtin Exception-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\02 User Defined Exception in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['User Defined Exception in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\02 User Defined Exception in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['User Defined Exception in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\03 Difference between Error and Exception and Warning in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Error, Exception and Warning.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\14 Exception Handling\03 Difference between Error and Exception and Warning in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Error, Exception and Warning-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments
# Directories:  ['14.1 Installing VSCode and Coding in VSCode', '14.2 Debugging in VSCode', '14.3 Introduction to Virtual Environments', '14.4 Using conda and Virtual Envrionrments with VSCode', 'VSCODE']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\14.1 Installing VSCode and Coding in VSCode
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\14.2 Debugging in VSCode
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\14.3 Introduction to Virtual Environments
# Directories:  []
# Files:  ['Introduction to Virtual Environments.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\14.4 Using conda and Virtual Envrionrments with VSCode
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\VSCODE
# Directories:  ['__pycache__']
# Files:  ['calc.py', 'main.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\15 VSCode and Virtual Environments\VSCODE\__pycache__
# Directories:  []
# Files:  ['calc.cpython-310.pyc']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules
# Directories:  ['.ipynb_checkpoints', '01 Module in Python, Math Module in Python', '02 datetime Class in Python', '03 Python Counter in Collections with Example', '04 random and time method in Python', '05 functools, getpass and sys Module', '06 Python Regex Tutorial']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\01 Module in Python, Math Module in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Module in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\01 Module in Python, Math Module in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Module in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\02 datetime Class in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Datetime Module.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\02 datetime Class in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Datetime Module-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\03 Python Counter in Collections with Example
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Counter in Collections.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\03 Python Counter in Collections with Example\.ipynb_checkpoints
# Directories:  []
# Files:  ['Counter in Collections-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\04 random and time method in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Random Module.ipynb', 'time Module.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\04 random and time method in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Random Module-checkpoint.ipynb', 'time Module-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\05 functools, getpass and sys Module
# Directories:  ['.ipynb_checkpoints', 'arguments']
# Files:  ['functools and memoization.ipynb', 'getpass() and getuser() in Python.ipynb', 'sys module in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\05 functools, getpass and sys Module\.ipynb_checkpoints
# Directories:  []
# Files:  ['functools and memoization-checkpoint.ipynb', 'functools-checkpoint.ipynb', 'getpass() and getuser() in Python-checkpoint.ipynb', 'sys module in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\05 functools, getpass and sys Module\arguments
# Directories:  []
# Files:  ['test.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\06 Python Regex Tutorial
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Regex in Python.ipynb', 'Regex Module in Python-Copy1.ipynb', 'Regex Module in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\16 Modules\06 Python Regex Tutorial\.ipynb_checkpoints
# Directories:  []
# Files:  ['Regex in Python-checkpoint.ipynb', 'Regex Module in Python-checkpoint.ipynb', 'Regex Module in Python-Copy1-checkpoint.ipynb', 'Regex Module-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling
# Directories:  ['.ipynb_checkpoints', '01 What is File and File Handling', '02 Reading Files in Python', '03 Write Create Files in Python']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\.ipynb_checkpoints
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\01 What is File and File Handling
# Directories:  ['.ipynb_checkpoints']
# Files:  ['test_file.txt', 'What is file and file handling.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\01 What is File and File Handling\.ipynb_checkpoints
# Directories:  []
# Files:  ['What is file and file handling-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\02 Reading Files in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['file.txt', 'file1.txt', 'PythonApplication.jpg', 'Reading files in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\02 Reading Files in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Reading files in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\03 Write Create Files in Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['file.txt', 'file2.txt', 'file_a.txt', 'file_w.txt', 'file_x.txt', 'myfile.txt', 'myfile1.txt', 'myfile2.txt', 'Write Create Files in Python.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\17 File Handling\03 Write Create Files in Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['Write Create Files in Python-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Exercises
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Assignment 1.gform', 'Assignment 10 - Set.ipynb', 'Assignment 11 - Dictionary.ipynb', 'Assignment 12 - Function Exercise 1 ( Up to Recursive Function).ipynb', 'Assignment 13 - Lambda Function.ipynb', 'Assignment 14 - Function Decorator.ipynb', 'Assignment 15 - Ternary If.ipynb', 'Assignment 16 - Comprehension.ipynb', 'Assignment 17 - Generators.ipynb', 'Assignment 18 - type and instance.ipynb', 'Assignment 19 - Len, min, max, sorted.ipynb', 'Assignment 2.gform', 'Assignment 20 - Zip, map, filter.ipynb', 'Assignment 21 - OOP.ipynb', 'Assignment 3 - User Inputs, Print Statements.ipynb', 'Assignment 4 - Conditional Statements.ipynb', 'Assignment 5 - For Loop.ipynb', 'Assignment 6 - While Loops.ipynb', 'Assignment 7 - Strings in Python.ipynb', 'Assignment 8 - List.ipynb', 'Assignment 9 -  Tuple.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Exercises\.ipynb_checkpoints
# Directories:  []
# Files:  ['Assignment 10 - Set-checkpoint.ipynb', 'Assignment 11 - Dictionary-checkpoint.ipynb', 'Assignment 12 - Function Exercise 1 ( Up to Recursive Function)-checkpoint.ipynb', 'Assignment 13 - Lambda Function-checkpoint.ipynb', 'Assignment 14 - Function Decorator-checkpoint.ipynb', 'Assignment 15 - Ternary If-checkpoint.ipynb', 'Assignment 16 - Comprehension-checkpoint.ipynb', 'Assignment 17 - Generators-checkpoint.ipynb', 'Assignment 18 - Len, min, max, sorted-checkpoint.ipynb', 'Assignment 18 - type and instance-checkpoint.ipynb', 'Assignment 20 - Zip, map, filter-checkpoint.ipynb', 'Assignment 21 - OOP-checkpoint.ipynb', 'Assignment 3 - User Inputs, Print Statements-checkpoint.ipynb', 'Assignment 4 - Conditional Statements-checkpoint.ipynb', 'Assignment 5 - For Loop-checkpoint.ipynb', 'Assignment 6 - While Loops-checkpoint.ipynb', 'Assignment 7 - Strings in Python-checkpoint.ipynb', 'Assignment 8 - List-checkpoint.ipynb', 'Assignment 9 -  Tuple-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works
# Directories:  ['Calculator', 'Image Manipulation']
# Files:  ['bank.py', 'Calculator.zip', 'card_game.py', 'chromedriver.exe', 'CountryByPopulation.csv', 'quotes.py', 'quotes.txt', 'sele.py', 'wikipedia.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Calculator
# Directories:  ['build', 'dist']
# Files:  ['calc.ico', 'calc.png', 'calc.qrc', 'calc.ui', 'calculator.py', 'calculator.spec', 'Commands.txt', 'image_file.py', 'test.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Calculator\build
# Directories:  ['calculator']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Calculator\build\calculator
# Directories:  ['localpycs']
# Files:  ['Analysis-00.toc', 'base_library.zip', 'calculator.exe.manifest', 'calculator.pkg', 'EXE-00.toc', 'PKG-00.toc', 'PYZ-00.pyz', 'PYZ-00.toc', 'warn-calculator.txt', 'xref-calculator.html']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Calculator\build\calculator\localpycs
# Directories:  []
# Files:  ['pyimod01_archive.pyc', 'pyimod02_importers.pyc', 'pyimod03_ctypes.pyc', 'pyimod04_pywin32.pyc', 'struct.pyc']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Calculator\dist
# Directories:  []
# Files:  ['calculator.exe']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Image Manipulation
# Directories:  ['Input', 'Output', '__pycache__']
# Files:  ['image_manipulation.py', 'user.py']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Image Manipulation\Input
# Directories:  []
# Files:  ['Dragon1.jpg', 'Dragon2.jpg', 'Dragon3.jpg']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Image Manipulation\Output
# Directories:  []
# Files:  ['Resize.jpg', 'Resized.png', 'Thumbnail.png']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Project Works\Image Manipulation\__pycache__
# Directories:  []
# Files:  ['image_manipulation.cpython-310.pyc', 'user.cpython-310.pyc']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects
# Directories:  ['.git', '.vscode', '01 Mad Lib Generator', '02 Guess a Number', '03 Rock Paper Scissors', '04 Web Scrapping', '05 PyQT GUI', '06 Image Manipulation', '07 OOP Project']
# Files:  ['README.md']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git
# Directories:  ['hooks', 'info', 'logs', 'objects', 'refs']
# Files:  ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\hooks
# Directories:  []
# Files:  ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'update.sample']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\info
# Directories:  []
# Files:  ['exclude']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\logs
# Directories:  ['refs']
# Files:  ['HEAD']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\logs\refs
# Directories:  ['heads', 'remotes']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\logs\refs\heads
# Directories:  []
# Files:  ['main']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\logs\refs\remotes
# Directories:  ['origin']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\logs\refs\remotes\origin
# Directories:  []
# Files:  ['HEAD', 'main']
#
# Current Path:  E:\NextStepInfoTechCourses\10 Python 10\Python-Projects\.git\objects
# ...
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\94
# Directories:  []
# Files:  ['5a71e7f452c355d65e7e13553e5356fff57264', '802e0ba2cdfdd8aba11ed357b4ffbd8ba65025']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\96
# Directories:  []
# Files:  ['40442d25174005a4eb1ad2bd686613aa786a71']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\9a
# Directories:  []
# Files:  ['23f1eeb0dcc1b7102057790da0ea43c15cdfd7', '4abd7d6657ac67ee8c0649e8563524c85f8596', '8fb32d0a0d720d659c3f42a0cb0bf7d4190f45']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\9f
# Directories:  []
# Files:  ['78c8ac1c36f1f5035dadd4e79b6b1333359e13']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\a4
# Directories:  []
# Files:  ['40ea01f5910ae84c4d60d57695babe8ef065f5', '48e69cb9d23461c8a13ca5c5c90bdcc7a9a9e7']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\a9
# Directories:  []
# Files:  ['42b4ee1609241d4c06a2496d67b577093d5c32']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\ab
# Directories:  []
# Files:  ['14620d37d27aa9c4f7ae678bbd37700a6afd3b', 'd12f067505287f2e207ccd0907ba564e9fedec']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\b1
# Directories:  []
# Files:  ['f3725676a1eb159de740cc5031e4198f7d8e32']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\b4
# Directories:  []
# Files:  ['f965de9eb610781a86f4c76e3c0cca0667dc1a']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\b8
# Directories:  []
# Files:  ['19d86dad9fbf7c8bc2a6958b4875a75e4c42ec', '585994118d594b6438a8f41ef9b15af76773dc']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\bb
# Directories:  []
# Files:  ['f8433ac4920fd9586317ee6dfaf7168148d9e2']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\bd
# Directories:  []
# Files:  ['b7ca4b50d25541a9d60ca89a77d4671db171b7']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\be
# Directories:  []
# Files:  ['b412a6dd8d5f2acc66a2b8acf36e371f7ac5d7']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\c1
# Directories:  []
# Files:  ['6158b09413e619c700f745a6640237fa3c498f']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\c5
# Directories:  []
# Files:  ['adf7e1590c31d3abd013ebf8ca9e0ed1282c9b']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\c6
# Directories:  []
# Files:  ['fdb5082962fe32b366f4dcbe219ce04a46d3bd']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\c8
# Directories:  []
# Files:  ['427228d870ae373db3b942b192e877184b38de']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\cc
# Directories:  []
# Files:  ['de7c08bad14efb5b2e78368af80821a93dacb6']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\cd
# Directories:  []
# Files:  ['46c9c36f4a517d37f034a406564592283a1830']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\d0
# Directories:  []
# Files:  ['22f669c5136b47257db8abf59ea04314105786']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\d2
# Directories:  []
# Files:  ['3622ff1b5cc1004fc84e4049f9dcbfb53e4ee2', '62388595a224b91ecda7dec908438dfe7375bc', 'b59bf44506db177c92a34579661bd849e2c1f4']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\d6
# Directories:  []
# Files:  ['b73b3ecd02d6f1b12c01be598b3bf3cd0ec70f']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\db
# Directories:  []
# Files:  ['4ddb9cdaaf9080620d7b55eb2d07e997fe4b5d', '85c5cb960ab427498c70c58746d29154b42af1', 'ab0695a524baef7b14527cd6207493743e2003', 'b81608913d3b9c8794db4f267315fcc895d053']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\dd
# Directories:  []
# Files:  ['58e1ff59d51e21808858495b0c166c17f47d01']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\de
# Directories:  []
# Files:  ['288e1eab6a537caed290ce0fc5e70be7ae9dba']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\df
# Directories:  []
# Files:  ['019acb191ffdbc07b4a29e203a10ab42b094eb']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\e4
# Directories:  []
# Files:  ['4a424cf0f8df116ea9d9429de16595d7b8a673']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\e9
# Directories:  []
# Files:  ['377a559409f2397184020a46ccfd0df1c8824d']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\ec
# Directories:  []
# Files:  ['3ba4835e92897659c285c7440ce5f084057f6d']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\ed
# Directories:  []
# Files:  ['308a66ea855c6896d95b59042f5d8f2ff316a2']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\f0
# Directories:  []
# Files:  ['384bbc701fe55857a48323cf66f63d550e06dd']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\f2
# Directories:  []
# Files:  ['f6eae1f6bb80746fc302e17c108a2d00ec0b26']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\f3
# Directories:  []
# Files:  ['491a538ff36de5e1fdb17d382e0f595f559c7e']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\fb
# Directories:  []
# Files:  ['f3a37bed93e0871652489b7cf0572ac539dfe7']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\info
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\objects\pack
# Directories:  []
# Files:  ['pack-f942c8d0f8b1106fdb5a3f02ea779ac2ec9b5a85.idx', 'pack-f942c8d0f8b1106fdb5a3f02ea779ac2ec9b5a85.pack']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\refs
# Directories:  ['heads', 'remotes', 'tags']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\refs\heads
# Directories:  []
# Files:  ['main']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\refs\remotes
# Directories:  ['origin']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\refs\remotes\origin
# Directories:  []
# Files:  ['HEAD', 'main']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.git\refs\tags
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\.vscode
# Directories:  []
# Files:  ['settings.json']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\01 Mad Lib Generator
# Directories:  []
# Files:  ['madlib_generator1.py', 'madlib_generator2.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\02 Guess a Number
# Directories:  []
# Files:  ['guess_a_number_computer.py', 'guess_a_number_user.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\03 Rock Paper Scissors
# Directories:  []
# Files:  ['rock_paper_scissors.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\04 Web Scrapping
# Directories:  []
# Files:  ['interest.py', 'promech.txt', 'Quotes.txt', 'quotes_scraping.py', 'test.py', 'wikipedia_table_scrapping.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\05 PyQT GUI
# Directories:  ['01 Calculator', '01 Interest Calculator']
# Files:  ['Commands.txt']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\05 PyQT GUI\01 Calculator
# Directories:  ['__pycache__']
# Files:  ['calculator.py', 'main.py', 'ui_calculator.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\05 PyQT GUI\01 Calculator\__pycache__
# Directories:  []
# Files:  ['calculator.cpython-39.pyc', 'ui_calculator.cpython-39.pyc']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\05 PyQT GUI\01 Interest Calculator
# Directories:  []
# Files:  ['simple_interest_calculator.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation
# Directories:  ['Add Logo', 'Image Changer']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation\Add Logo
# Directories:  ['WallpaperPC', 'WallpaperPCwithLogo']
# Files:  ['Add_Logo_In_Images.ipynb', 'firebird.png', 'logo_adder.py', 'README.md']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation\Add Logo\WallpaperPC
# Directories:  []
# Files:  ['0-9577_pc-desktop-wallpaper-popular-desktop-backgrounds.jpg', '0l6u3w96nxj31.jpg', '1-10529_computer-wallpapers-hd-free-download-group-windows-desktop.jpg', '1-10721_hd-beach-desktop-wallpaper-beach-wallpapers-best-wallpapers.jpg', '1-IZQauWoP_TTqwlEiPXNv_w.jpeg', '123456789-8.jpg', '164026900-asus-rog-wallpapers.jpg', '164313510-game-wallpapers.jpg', '164575106-nes-wallpapers.jpg', '164698273-roccat-wallpapers.jpg', '164902441-video-game-wallpapers.jpg', '53893008.jpg', 'beautiful-wallpapers-hd-images-2.jpg', 'best-4k-wallpapers-for-pc_2.jpg', 'Best-Avengers-Endgame-Avengers-4-Wallpapers-for-Desktop-and-Mobile-1_4d470f76dc99e18ad75087b1b8410ea9.jpg', 'Best-Avengers-Endgame-Avengers-4-Wallpapers-for-Desktop-and-Mobile-4_4d470f76dc99e18ad75087b1b8410ea9.jpg', 'Best-Avengers-Endgame-Avengers-4-Wallpapers-for-Desktop-and-Mobile-6_4d470f76dc99e18ad75087b1b8410ea9.jpg', 'Best-Captain-Marvel-Wallpapers-6_4d470f76dc99e18ad75087b1b8410ea9.jpg', 'best-desktop-wallpaper-1920x1200-hd-3.jpg', 'best-desktop-wallpapers.jpg', 'desktop-hd-wallpapers-2018-44.jpg', 'Desktop-Wallpaper-18.jpg', 'Desktop-Wallpaper-23.jpg', 'Desktop-Wallpaper-33.jpg', 'Desktop-Wallpaper-34.jpg', 'Desktop-Wallpaper-4.jpg', 'desktop-wallpaper-free-download.jpg', 'desktop-wallpaper-hd-15.jpg', 'desktop-wallpaper-hd-2.jpg', 'desktop-wallpaper-hd-3d-full-screen-free-download.jpg', 'desktop-wallpaper-hd-3d-full-screen.jpg', 'desktop-wallpaper-hd-7.jpg', 'desktop-wallpaper-hd-full-screen-nature.jpg', 'desktop-wallpaper-hd-nature.jpg', 'desktop-wallpaper-hd-nature_2.jpg', 'desktop-wallpaper-hd-widescreen-4.jpg', 'desktop-wallpaper-pictures.jpg', 'desktop-wallpapers-6.jpg', 'desktop-wallpapers-hd-13.jpg', 'doctor-strange-marvel-mcu-mage.jpg']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation\Add Logo\WallpaperPCwithLogo
# Directories:  []
# Files:  ['Image0.jpg', 'Image1.jpg', 'Image10.jpg', 'Image11.jpg', 'Image12.jpg', 'Image13.jpg', 'Image14.jpg', 'Image15.jpg', 'Image16.jpg', 'Image17.jpg', 'Image18.jpg', 'Image19.jpg', 'Image2.jpg', 'Image20.jpg', 'Image21.jpg', 'Image22.jpg', 'Image23.jpg', 'Image24.jpg', 'Image25.jpg', 'Image26.jpg', 'Image27.jpg', 'Image28.jpg', 'Image29.jpg', 'Image3.jpg', 'Image30.jpg', 'Image31.jpg', 'Image32.jpg', 'Image33.jpg', 'Image34.jpg', 'Image35.jpg', 'Image36.jpg', 'Image37.jpg', 'Image38.jpg', 'Image39.jpg', 'Image4.jpeg', 'Image5.jpg', 'Image6.jpg', 'Image7.jpg', 'Image8.jpg', 'Image9.jpg']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation\Image Changer
# Directories:  ['720']
# Files:  ['Dragon1.jpg', 'Dragon2.jpg', 'Dragon3.jpg', 'modifier.py']
#
# Current Path:  E:\NextStepInfoTechCourses\PythonProgramming\PythonProgramming\For Teacher\Python-Projects\06 Image Manipulation\Image Changer\720
# Directories:  []
# Files:  ['Dragon1_thumbnail_720_.jpg', 'Dragon2_thumbnail_720_.jpg', 'Dragon3_thumbnail_720_.jpg']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects
# Directories:  ['BMC', 'Game Development With Python', 'New folder', 'Reference']
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\BMC
# Directories:  ['.ipynb_checkpoints', 'Intro', 'Intro2']
# Files:  ['01 Introduction to Jupyter Notebook.ipynb', '02 Python Bootcamp.ipynb', 'Introduction To Python.pptx']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\BMC\.ipynb_checkpoints
# Directories:  []
# Files:  ['02 Python Bootcamp-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\BMC\Intro
# Directories:  ['.ipynb_checkpoints']
# Files:  ['Intro to Jupyter Notebook.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\BMC\Intro\.ipynb_checkpoints
# Directories:  []
# Files:  ['Intro to Jupyter Notebook-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\BMC\Intro2
# Directories:  []
# Files:  []
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\Game Development With Python
# Directories:  ['.ipynb_checkpoints']
# Files:  ['01 Introduction to Jupyter Notebook.ipynb', '02 Python Bootcamp.ipynb', 'download.png', 'Intro.ipynb', 'Introduction To Python.pptx', 'test.py', 'TicTacToe.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\Game Development With Python\.ipynb_checkpoints
# Directories:  []
# Files:  ['01 Introduction to Jupyter Notebook-checkpoint.ipynb', '02 Python Bootcamp-checkpoint.ipynb', 'Intro-checkpoint.ipynb', 'TicTacToe-checkpoint.ipynb', 'tiktactoe-checkpoint.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\New folder
# Directories:  []
# Files:  ['countdown.py']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\Reference
# Directories:  ['.ipynb_checkpoints']
# Files:  ['01 Introduction to Jupyter Notebook.ipynb', '02 Python Bootcamp.ipynb', 'Introduction To Python.pptx', 'Python Bootcamp.ipynb', 'TicTacToe.ipynb']
#
# Current Path:  E:\NextStepInfoTechCourses\WorkshopProjects\Reference\.ipynb_checkpoints
# Directories:  []
# Files:  ['01 Introduction to Jupyter Notebook-checkpoint.ipynb', '02 Python Bootcamp-checkpoint.ipynb', 'Intro-checkpoint.ipynb', 'Python Bootcamp-checkpoint.ipynb', 'TicTacToe-checkpoint.ipynb', 'tiktactoe-checkpoint.ipynb']

# %% [markdown]
# ## 7. os.environ

# %%
help(os.environ)
# Out:
# Help on _Environ in module os object:
#
# class _Environ(collections.abc.MutableMapping)
#  |  _Environ(data, encodekey, decodekey, encodevalue, decodevalue)
#  |
#  |  Method resolution order:
#  |      _Environ
#  |      collections.abc.MutableMapping
#  |      collections.abc.Mapping
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delitem__(self, key)
#  |
#  |  __getitem__(self, key)
#  |
#  |  __init__(self, data, encodekey, decodekey, encodevalue, decodevalue)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, other)
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
#  |
#  |  __or__(self, other)
#  |      Return self|value.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __ror__(self, other)
#  |      Return value|self.
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  copy(self)
#  |
#  |  setdefault(self, key, value)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from collections.abc.MutableMapping:
#  |
#  |  clear(self)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  pop(self, key, default=<object object at 0x0000017442398180>)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised.
#  |
#  |  popitem(self)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair
#  |      as a 2-tuple; but raise KeyError if D is empty.
#  |
#  |  update(self, other=(), /, **kwds)
#  |      D.update([E, ]**F) -> None.  Update D from mapping/iterable E and F.
#  |      If E present and has a .keys() method, does:     for k in E: D[k] = E[k]
#  |      If E present and lacks .keys() method, does:     for (k, v) in E: D[k] = v
#  |      In either case, this is followed by: for k, v in F.items(): D[k] = v
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from collections.abc.Mapping:
#  |
#  |  __contains__(self, key)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  get(self, key, default=None)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(self)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(self)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  values(self)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from collections.abc.Mapping:
#  |
#  |  __hash__ = None
#  |
#  |  __reversed__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from collections.abc.Collection:
#  |
#  |  __subclasshook__(C) from abc.ABCMeta
#  |      Abstract classes can override this to customize issubclass().
#  |
#  |      This is invoked early on by abc.ABCMeta.__subclasscheck__().
#  |      It should return True, False or NotImplemented.  If it returns
#  |      NotImplemented, the normal algorithm is used.  Otherwise, it
#  |      overrides the normal algorithm (and the outcome is cached).
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from collections.abc.Iterable:
#  |
#  |  __class_getitem__ = GenericAlias(...) from abc.ABCMeta
#  |      Represent a PEP 585 generic type
#  |
#  |      E.g. for t = list[int], t.__origin__ is list and t.__args__ is (int,).

# %%
os.environ.get('OneDrive')
# Out:
# 'C:\\Users\\HP\\OneDrive'

# %% [markdown]
# ## 8. os.path

# %%
help(os.path)
# Out:
# Help on module ntpath:
#
# NAME
#     ntpath - Common pathname manipulations, WindowsNT/95 version.
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/ntpath.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Instead of importing this module directly, import os and refer to this
#     module as os.path.
#
# FUNCTIONS
#     abspath(path)
#         Return the absolute version of a path.
#
#     basename(p)
#         Returns the final component of a pathname
#
#     commonpath(paths)
#         Given a sequence of path names, returns the longest common sub-path.
#
#     commonprefix(m)
#         Given a list of pathnames, returns the longest common leading component
#
#     dirname(p)
#         Returns the directory component of a pathname
#
#     exists(path)
#         Test whether a path exists.  Returns False for broken symbolic links
#
#     expanduser(path)
#         Expand ~ and ~user constructs.
#
#         If user or $HOME is unknown, do nothing.
#
#     expandvars(path)
#         Expand shell variables of the forms $var, ${var} and %var%.
#
#         Unknown variables are left unchanged.
#
#     getatime(filename)
#         Return the last access time of a file, reported by os.stat().
#
#     getctime(filename)
#         Return the metadata change time of a file, reported by os.stat().
#
#     getmtime(filename)
#         Return the last modification time of a file, reported by os.stat().
#
#     getsize(filename)
#         Return the size of a file, reported by os.stat().
#
#     isabs(s)
#         Test whether a path is absolute
#
#     isdir(s)
#         Return true if the pathname refers to an existing directory.
#
#     isfile(path)
#         Test whether a path is a regular file
#
#     islink(path)
#         Test whether a path is a symbolic link.
#         This will always return false for Windows prior to 6.0.
#
#     ismount(path)
#         Test whether a path is a mount point (a drive root, the root of a
#         share, or a mounted volume)
#
#     join(path, *paths)
#         # Join two (or more) paths.
#
#     lexists(path)
#         Test whether a path exists.  Returns True for broken symbolic links
#
#     normcase(s)
#         Normalize case of pathname.
#
#         Makes all characters lowercase and all slashes into backslashes.
#
#     normpath(path)
#         Normalize path, eliminating double slashes, etc.
#
#     realpath(path, *, strict=False)
#
#     relpath(path, start=None)
#         Return a relative version of a path
#
#     samefile(f1, f2)
#         Test whether two pathnames reference the same actual file or directory
#
#         This is determined by the device number and i-node number and
#         raises an exception if an os.stat() call on either pathname fails.
#
#     sameopenfile(fp1, fp2)
#         Test whether two open file objects reference the same file
#
#     samestat(s1, s2)
#         Test whether two stat buffers reference the same file
#
#     split(p)
#         Split a pathname.
#
#         Return tuple (head, tail) where tail is everything after the final slash.
#         Either part may be empty.
#
#     splitdrive(p)
#         Split a pathname into drive/UNC sharepoint and relative path specifiers.
#         Returns a 2-tuple (drive_or_unc, path); either part may be empty.
#
#         If you assign
#             result = splitdrive(p)
#         It is always true that:
#             result[0] + result[1] == p
#
#         If the path contained a drive letter, drive_or_unc will contain everything
#         up to and including the colon.  e.g. splitdrive("c:/dir") returns ("c:", "/dir")
#
#         If the path contained a UNC path, the drive_or_unc will contain the host name
#         and share up to but not including the fourth directory separator character.
#         e.g. splitdrive("//host/computer/dir") returns ("//host/computer", "/dir")
#
#         Paths cannot contain both a drive letter and a UNC path.
#
#     splitext(p)
#         Split the extension from a pathname.
#
#         Extension is everything from the last dot to the end, ignoring
#         leading dots.  Returns "(root, ext)"; ext may be empty.
#
# DATA
#     __all__ = ['normcase', 'isabs', 'join', 'splitdrive', 'split', 'splite...
#     altsep = '/'
#     curdir = '.'
#     defpath = r'.;C:\bin'
#     devnull = 'nul'
#     extsep = '.'
#     pardir = '..'
#     pathsep = ';'
#     sep = r'\'
#     supports_unicode_filenames = True
#
# FILE
#     c:\users\hp\appdata\local\programs\python\python310\lib\ntpath.py

# %%
help(os.path.join)
# Out:
# Help on function join in module ntpath:
#
# join(path, *paths)
#     # Join two (or more) paths.

# %%
os.path.join("TestFile2.txt")
# Out:
# 'TestFile2.txt'

# %%
os.path.join(os.environ.get("OneDrive"), "TestFile2.txt")
# Out:
# 'C:\\Users\\HP\\OneDrive\\TestFile2.txt'

# %%
help(os.path.basename)
# Out:
# Help on function basename in module ntpath:
#
# basename(p)
#     Returns the final component of a pathname

# %%
print(os.path.basename(r"E:\NextStepInfoTechCourses\TestFile2.txt"))
# Out:
# TestFile2.txt

# %%
print(os.path.split(r"E:\NextStepInfoTechCourses\TestFile2.txt"))
# Out:
# ('E:\\NextStepInfoTechCourses', 'TestFile2.txt')

# %%
print(os.path.exists(r"E:\NextStepInfoTechCourses\TestFile2.txt"))
# Out:
# True

# %%
print(os.path.exists(r"E:\NextStepInfoTechCourses\TestFile3.txt"))
# Out:
# False

# %%
print(os.path.isdir(r"E:\NextStepInfoTechCourses\TestFile2.txt"))
# Out:
# False

# %%
print(os.path.isdir(r"E:\NextStepInfoTechCourses"))
# Out:
# True

# %%
print(os.path.isfile(r"E:\NextStepInfoTechCourses\TestFile2.txt"))
# Out:
# True

# %%
help(os.path.isfile)
# Out:
# Help on function isfile in module genericpath:
#
# isfile(path)
#     Test whether a path is a regular file

# %%
print(os.path.isfile(r"E:\NextStepInfoTechCourses"))
# Out:
# False
